# %% [markdown]
# Mini-projet : Visualisation de données avec Pandas, Seaborn et Matplotlib

# %% [markdown]
# Chargement et nettoyage des données et Analyse exploratoire des données (AED) :

# %%
import pandas as pd

# %%
df = pd.read_csv('Palmer Penguins Dataset.csv')

# %%
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
df.describe(include="all")
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex         year
# count    342.000000   333   344.000000
# ...

# %%
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
df['bill_length_mm'] = df['bill_length_mm'].ffill()
df['bill_depth_mm'] = df['bill_depth_mm'].ffill()

# %%
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen            40.3           18.0                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
df.fillna( {
    'flipper_length_mm' : df["flipper_length_mm"].mean(),
    'body_mass_g': df["body_mass_g"].mean()
    
}

)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7         181.000000
# 1       Adelie  Torgersen            39.5           17.4         186.000000
# 2       Adelie  Torgersen            40.3           18.0         195.000000
# 3       Adelie  Torgersen            40.3           18.0         200.915205
# 4       Adelie  Torgersen            36.7           19.3         193.000000
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8         207.000000
# 340  Chinstrap      Dream            43.5           18.1         202.000000
# 341  Chinstrap      Dream            49.6           18.2         193.000000
# 342  Chinstrap      Dream            50.8           19.0         210.000000
# 343  Chinstrap      Dream            50.2           18.7         198.000000
#
#      body_mass_g     sex  year
# ...

# %%
df.iloc[200:210]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 200  Gentoo  Biscoe            44.9           13.3              213.0
# 201  Gentoo  Biscoe            45.2           15.8              215.0
# 202  Gentoo  Biscoe            46.6           14.2              210.0
# 203  Gentoo  Biscoe            48.5           14.1              220.0
# 204  Gentoo  Biscoe            45.1           14.4              210.0
# 205  Gentoo  Biscoe            50.1           15.0              225.0
# 206  Gentoo  Biscoe            46.5           14.4              217.0
# 207  Gentoo  Biscoe            45.0           15.4              220.0
# 208  Gentoo  Biscoe            43.8           13.9              208.0
# 209  Gentoo  Biscoe            45.5           15.0              220.0
#
#      body_mass_g     sex  year
# 200       5100.0  female  2008
# 201       5300.0    male  2008
# 202       4850.0  female  2008
# 203       5300.0    male  2008
# 204       4400.0  female  2008
# ...

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
nan_index = df[df['flipper_length_mm'].isna()].index
print(nan_index)
# Out:
# Index([3, 271], dtype='int64')

# %%
df.iloc[270:279]
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 270     Gentoo  Biscoe            47.2           13.7              214.0
# 271     Gentoo  Biscoe            47.2           13.7                NaN
# 272     Gentoo  Biscoe            46.8           14.3              215.0
# 273     Gentoo  Biscoe            50.4           15.7              222.0
# 274     Gentoo  Biscoe            45.2           14.8              212.0
# 275     Gentoo  Biscoe            49.9           16.1              213.0
# 276  Chinstrap   Dream            46.5           17.9              192.0
# 277  Chinstrap   Dream            50.0           19.5              196.0
# 278  Chinstrap   Dream            51.3           19.2              193.0
#
#      body_mass_g     sex  year
# 270       4925.0  female  2009
# 271          NaN     NaN  2009
# 272       4850.0  female  2009
# 273       5750.0    male  2009
# 274       5200.0  female  2009
# 275       5400.0    male  2009
# ...

# %%
df = df.dropna(subset=['sex'])

# %%
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
df.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# Tâches de visualisation :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data = df , x = "species" , palette= "deep"  )
# Out:
# C:\Users\bayac\AppData\Local\Temp\ipykernel_7576\152427330.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df , x = "species" , palette= "deep"  )
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.scatterplot( data = df , x ="flipper_length_mm" ,y = "body_mass_g" , palette= 'plasma' , hue = "species" )
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
island_counts = df['island'].value_counts()

# %%
island_counts
# Out:
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
plt.pie( island_counts , labels= island_counts.index , colors= sns.color_palette('pastel') , autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1f785ff7750>,
# ...
#  [Text(0.036315111222426345, 1.0994003878009608, 'Biscoe'),
#   Text(-0.5044682329378414, -0.9775028398713591, 'Dream'),
#   Text(0.9936243679250859, -0.4719222557429072, 'Torgersen')],
#  [Text(0.019808242484959823, 0.599672938800524, '48.9%'),
#   Text(-0.275164490693368, -0.5331833672025594, '36.9%'),
#   Text(0.5419769279591377, -0.2574121394961312, '14.1%')])

# %%
sns.countplot(data=df, x='species', hue='sex', palette='Set2')
plt.title("Répartition des sexes par espèce")
# Out:
# Text(0.5, 1.0, 'Répartition des sexes par espèce')

# %%
numeric_df = df.select_dtypes(include='number')
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
measurements = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']

for col in measurements:
    plt.figure(figsize=(6,4))
    sns.boxplot(data=df, x='species', y=col, palette='Set2')
    plt.title(f"Diagramme en boîte de {col} par espèce")
# Out:
# C:\Users\bayac\AppData\Local\Temp\ipykernel_7576\4224834502.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='species', y=col, palette='Set2')
# C:\Users\bayac\AppData\Local\Temp\ipykernel_7576\4224834502.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='species', y=col, palette='Set2')
# C:\Users\bayac\AppData\Local\Temp\ipykernel_7576\4224834502.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='species', y=col, palette='Set2')
# ...
