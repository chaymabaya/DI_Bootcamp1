# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.read_csv('Iris_dataset.csv')

# %%
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
info_data= {
    "Nom_et_prénom" : ["chaymae baya " , "zineb lahraoui " , "mehdi jamlaoui " , "mohammed majjadi" , "kaouthar chakor"] ,
    "CNE" : ["E13119762" , "E14119661" , "E15119764" , "C16120762" , "R14119762" ] ,
     "notes" : [15 , 17 , 12 , 20 , 16] ,
      "Mention": ["Bien", "Très Bien", "Passable", "Très Bien", "Bien"] ,
     "Filière": ["électronique ", "IA", "Mécanique ", "physique", "Télecommunication"] ,
     "Date_naissance": ["2000-02-22", "2000-02-28", "1999-10-07", "2001-12-01", "2001-06-22"] ,
    "Telephone": [ "0612345678", "0623456789",  "0634567890",  "0645678901", "0656789012"]
}

# %%
df = pd.DataFrame(info_data)

# %%
df
# Out:
#       Nom_et_prénom        CNE  notes    Mention            Filière  \
# 0     chaymae baya   E13119762     15       Bien      électronique
# 1   zineb lahraoui   E14119661     17  Très Bien                 IA
# 2   mehdi jamlaoui   E15119764     12   Passable         Mécanique
# 3  mohammed majjadi  C16120762     20  Très Bien           physique
# 4   kaouthar chakor  R14119762     16       Bien  Télecommunication
#
#   Date_naissance   Telephone
# 0     2000-02-22  0612345678
# 1     2000-02-28  0623456789
# 2     1999-10-07  0634567890
# 3     2001-12-01  0645678901
# 4     2001-06-22  0656789012

# %%
df = df.set_index('Nom_et_prénom')

# %%
df
# Out:
#                         CNE  notes    Mention            Filière  \
# Nom_et_prénom
# chaymae baya      E13119762     15       Bien      électronique
# zineb lahraoui    E14119661     17  Très Bien                 IA
# mehdi jamlaoui    E15119764     12   Passable         Mécanique
# mohammed majjadi  C16120762     20  Très Bien           physique
# kaouthar chakor   R14119762     16       Bien  Télecommunication
#
#                  Date_naissance   Telephone
# Nom_et_prénom
# chaymae baya         2000-02-22  0612345678
# zineb lahraoui       2000-02-28  0623456789
# mehdi jamlaoui       1999-10-07  0634567890
# mohammed majjadi     2001-12-01  0645678901
# kaouthar chakor      2001-06-22  0656789012

# %%
df.sort_index()
# Out:
#                         CNE  notes    Mention            Filière  \
# Nom_et_prénom
# chaymae baya      E13119762     15       Bien      électronique
# kaouthar chakor   R14119762     16       Bien  Télecommunication
# mehdi jamlaoui    E15119764     12   Passable         Mécanique
# mohammed majjadi  C16120762     20  Très Bien           physique
# zineb lahraoui    E14119661     17  Très Bien                 IA
#
#                  Date_naissance   Telephone
# Nom_et_prénom
# chaymae baya         2000-02-22  0612345678
# kaouthar chakor      2001-06-22  0656789012
# mehdi jamlaoui       1999-10-07  0634567890
# mohammed majjadi     2001-12-01  0645678901
# zineb lahraoui       2000-02-28  0623456789

# %%
df.to_excel("info_data1.xlsx", index=False)

# %%
df.to_json("info_data2.json")

# %%
url = "https://jsonplaceholder.typicode.com/posts"

# %%
df = pd.read_json(url)

# %%
df
# Out:
#     userId   id                                              title  \
# 0        1    1  sunt aut facere repellat provident occaecati e...
# 1        1    2                                       qui est esse
# 2        1    3  ea molestias quasi exercitationem repellat qui...
# 3        1    4                               eum et est occaecati
# 4        1    5                                 nesciunt quas odio
# ..     ...  ...                                                ...
# 95      10   96  quaerat velit veniam amet cupiditate aut numqu...
# 96      10   97         quas fugiat ut perspiciatis vero provident
# 97      10   98                        laboriosam dolor voluptates
# 98      10   99  temporibus sit alias delectus eligendi possimu...
# 99      10  100              at nam consequatur ea labore ea harum
#
#                                                  body
# 0   quia et suscipit\nsuscipit recusandae consequu...
# ...

# %%
df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
