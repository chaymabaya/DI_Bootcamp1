# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['mini-projet.ipynb', 'US Superstore data.xls']

# %%
df = pd.read_excel("US Superstore data.xls")

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df["Sales"]
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
df["State"]
# Out:
# 0         Kentucky
# 1         Kentucky
# 2       California
# 3          Florida
# 4          Florida
#            ...
# 9989       Florida
# 9990    California
# 9991    California
# 9992    California
# 9993    California
# Name: State, Length: 9994, dtype: object

# %%
g=df.groupby("State")["Sales"].max().sort_values(ascending=False)
g
# Out:
# State
# Florida                 22638.480
# Indiana                 17499.950
# Washington              13999.960
# New York                11199.968
# Delaware                10499.970
# Michigan                 9892.740
# Minnesota                9449.950
# New Jersey               9099.930
# Virginia                 8749.950
# Pennsylvania             8399.976
# California               8187.650
# Texas                    8159.952
# North Carolina           7999.980
# Georgia                  6354.950
# Rhode Island             5399.910
# Missouri                 4899.930
# Nevada                   4535.976
# Ohio                     4499.985
# Vermont                  4404.900
# Kentucky                 3080.000
# Alabama                  3040.000
# Montana                  2999.950
# Wisconsin                2807.840
# Illinois                 2799.960
# Colorado                 2549.985
# Maryland                 2541.980
# Nebraska                 2479.960
# ...

# %%
g.head(5).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='State'>

# %%
df[ df['State'] == "New York" ][["Profit", "Sales", "State"]]
# Out:
#         Profit    Sales     State
# 53      6.2566    15.26  New York
# 54    298.6855  1029.95  New York
# 55     52.1400   208.56  New York
# 56     15.5520    32.40  New York
# 57      7.0980   319.41  New York
# ...        ...      ...       ...
# 9956   21.7845    46.35  New York
# 9957  109.7208   223.92  New York
# 9958    2.1900     7.30  New York
# 9984   15.1200    31.50  New York
# 9985   16.1240    55.60  New York
#
# [1128 rows x 3 columns]

# %%
df[ df['State'] == "California" ][["Profit", "Sales", "State"]]
# Out:
#        Profit    Sales       State
# 2      6.8714   14.620  California
# 5     14.1694   48.860  California
# 6      1.9656    7.280  California
# 7     90.7152  907.152  California
# 8      5.7825   18.504  California
# ...       ...      ...         ...
# 9986  15.2208   36.240  California
# 9990  15.6332   91.960  California
# 9991  19.3932  258.576  California
# 9992  13.3200   29.600  California
# 9993  72.9480  243.160  California
#
# [2001 rows x 3 columns]

# %%
ny_sales = df[df['State'] == "New York"]["Sales"].sum()
ca_sales = df[df['State'] == "California"]["Sales"].sum()
