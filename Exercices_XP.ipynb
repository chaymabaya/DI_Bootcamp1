# %% [markdown]
# <a href="https://colab.research.google.com/github/chaymabaya/DI_Bootcamp1/blob/master/Exercices_XP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **Exercice 1 : Introduction à l'analyse des données (Facile)**

# %% [markdown]
# Qu’est-ce que l’analyse de données ?
#
# L’analyse de données désigne l’ensemble des techniques et processus permettant de collecter, nettoyer, transformer, examiner et modéliser des données brutes afin d’extraire des renseignements utiles, de tirer des conclusions et de soutenir la prise de décision.
# Wikipédia
# En d’autres termes, on passe de données non structurées ou peu structurées à une information compréhensible et exploitable : on identifie des tendances, des corrélations, des anomalies, on crée des visualisations, on fait des hypothèses ou on construit des modèles prédictifs
# Pourquoi l'analyse des données est-elle importante dans les contextes modernes ?
# L’importance de l’analyse des données a explosé à l’ère du numérique pour plusieurs raisons :
# Elle permet de passer de décisions basées sur l’intuition à des décisions basées sur des preuves et des faits mesurables.
#
# Elle aide les organisations à mieux comprendre leurs clients, leurs marchés et à anticiper les changements. Par exemple, elles peuvent adapter leurs produits ou leurs services en fonction de données réelles.
# Elle contribue à optimiser les opérations, réduire les coûts, identifier les risques tôt et gagner un avantage concurrentiel dans un environnement où les données foisonnent.
#
# Enfin, dans un monde où les technologies (IoT, Big Data, IA) génèrent constamment des flux de données massifs, l’analyse est l’outil clé pour transformer ce « volume » en valeur réell

# %% [markdown]
#   **Exercice 2 :** **Dataset Loading and Initial**

# %% [markdown]
# data : How Much Sleep Do Americans Really Get

# %%
df= pd.read_csv('/content/sample_data/Time_Americans_Spend_Sleeping.csv')

# %%
df
# Out:
#      index  Year  Period  Avg hrs per day sleeping  Standard Error  \
# 0        0  2003  Annual                      8.57           0.018
# 1        1  2004  Annual                      8.55           0.026
# 2        2  2005  Annual                      8.62           0.023
# 3        3  2006  Annual                      8.63           0.024
# 4        4  2007  Annual                      8.57           0.024
# ..     ...   ...     ...                       ...             ...
# 940    940  2013  Annual                      8.83           0.085
# 941    941  2014  Annual                      8.98           0.086
# 942    942  2015  Annual                      8.83           0.074
# 943    943  2016  Annual                      8.92           0.071
# 944    944  2017  Annual                      8.81           0.091
#
#             Type of Days          Age Group  Activity    Sex
# 0               All days  15 years and over  Sleeping   Both
# ...

# %%
df.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
df.shape
# Out:
# (945, 9)

# %% [markdown]
# data : Global Trends in Mental Health Disorder

# %%
df1= pd.read_csv("/content/sample_data/Mental_health_Depression_disorder_Data.csv")
# Out:
# /tmp/ipython-input-3826008298.py:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1= pd.read_csv("/content/sample_data/Mental_health_Depression_disorder_Data.csv")

# %%
df1
# Out:
#          index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0            0  Afghanistan  AFG  1990           0.16056             0.697779
# 1            1  Afghanistan  AFG  1991          0.160312             0.697961
# 2            2  Afghanistan  AFG  1992          0.160135             0.698107
# 3            3  Afghanistan  AFG  1993          0.160037             0.698257
# 4            4  Afghanistan  AFG  1994          0.160022             0.698469
# ...        ...          ...  ...   ...               ...                  ...
# 108548  108548     Zimbabwe  ZWE  2013      303564.60359                  NaN
# 108549  108549     Zimbabwe  ZWE  2014     311665.769283                  NaN
# 108550  108550     Zimbabwe  ZWE  2015     320638.507158                  NaN
# 108551  108551     Zimbabwe  ZWE  2016     330437.353798                  NaN
# 108552  108552     Zimbabwe  ZWE  2017     340583.157405                  NaN
#
# ...

# %%
df1.shape
# Out:
# (108553, 11)

# %%
df1.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %% [markdown]
# data : Credit Card Approvals.

# %%
df2 = pd.read_csv("/content/sample_data/clean_dataset.csv")

# %%
df2
# Out:
#      Gender    Age    Debt  Married  BankCustomer         Industry Ethnicity  \
# 0         1  30.83   0.000        1             1      Industrials     White
# 1         0  58.67   4.460        1             1        Materials     Black
# 2         0  24.50   0.500        1             1        Materials     Black
# 3         1  27.83   1.540        1             1      Industrials     White
# 4         1  20.17   5.625        1             1      Industrials     White
# ..      ...    ...     ...      ...           ...              ...       ...
# 685       1  21.08  10.085        0             0        Education     Black
# 686       0  22.67   0.750        1             1           Energy     White
# 687       0  25.25  13.500        0             0       Healthcare    Latino
# 688       1  17.92   0.205        1             1  ConsumerStaples     White
# 689       1  35.00   3.375        1             1           Energy     Black
#
# ...

# %%
df2.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %% [markdown]
# **Exercice 3 : Identifying Data Types**

# %% [markdown]
# ▶ How Much Sleep Do Americans Really Get? :(colonnes typiques)
# Sleep Duration — Quantitative
# → nombre d’heures de sommeil (valeurs décimales possibles).
# Quality of Sleep — Quantitative
# → s’il s’agit d’un score (ex. 1–10) : numérique/ordinal. Si c’est une étiquette (Good/Fair/Poor) : qualitative ordinale.
# Age — Quantitative
# → âge en années (entier → discrète ; parfois enregistré en décimales).
# Gender — Qualitative
# → catégories (Male/Female/Other).
# Occupation — Qualitative
# → catégories professionnelles.
# Physical Activity Level — Peut être quantitative ou qualitative
# → si c’est un nombre (minutes d’activité) → quantitative continue ; si c’est Low/Medium/High → qualitative ordinale.
# Daily Steps — Quantitative
# → nombre de pas (entier).
# Stress Level — Quantitative
# → s’il s’agit d’un score numérique → quantitatif (ordinal si score discret). Sinon (Low/High) → qualitatif ordinal.
# BMI (Body Mass Index) — Quantitative
# → indice numérique.
# Has Sleep Disorder (oui/non) — Qualitative (binaire / nominal)
# → catégories oui/non.
# ▶ Global Trends in Mental Health Disorders (colonnes typiques)
# Country — Qualitative
# → nom du pays (catégorie).
# Year — Quantitative
# → année exprimée numériquement ; souvent traitée comme variable temporelle quantitative.
# Population — Quantitative
# → nombre d’habitants (entier).
# Depression (rate / cases) — Quantitative
# → taux (%) ou nombre de cas.
# Anxiety (rate / cases) — Quantitative
# Bipolar Disorder, Schizophrenia, Eating Disorders, etc. — Quantitative
# → taux ou nombre de cas par trouble.
# Age Group (si présent) — Qualitative
# → catégories d’âges (ex. 15–24, 25–34) — ordinale si les tranches ont un ordre.
# Sex (Male/Female) (si présent) — Qualitative
# ▶ Credit Card Approval Predictions (colonnes typiques)
# Gender — Qualitative
# Age — Quantitative
# Education Level — Qualitative
# → ex. High School < Bachelors < Masters (si niveaux ordonnés).
# Annual Income — Quantitative
# Debt (ou ExistingDebt) — Quantitative
# Credit Score — Quantitative
# Marital Status — Qualitative
# Number of Dependents — Quantitative
# Approval Status (target) — Qualitative

# %% [markdown]
# ** Exercice 4 : Exploring Data Types**

# %%
df3 = pd.read_csv("/content/sample_data/Iris.csv")

# %%
df3
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df3.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# pourquoi ces colonnes sont qualitatives ou quantitatives
# Colonnes quantitatives (numériques)
#
# Elles représentent des mesures, des valeurs numériques, ou des quantités.
#
# Id (numérique discret)
# -C’est un numéro unique attribué à chaque observation.
#
# SepalLengthCm (continue)
# - C’est une mesure réelle de longueur du sépale.
# SepalWidthCm (continue)
# -Mesure physique.
# PetalLengthCm (continue)
# - Longueur du pétale, mesurée en centimètres.
# PetalWidthCm (continue)
# -Largeur du pétale.

# %% [markdown]
# **Exercice 5 : Analyse de données de base avec Google Colab**

# %%
df3["SepalLengthCm"].std()
# Out:
# 0.8280661279778629

# %%
df3.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df3['SepalLengthCm'], df3['SepalWidthCm'])

# %%
plt.show()

# %% [markdown]
# **`Exercice 6 : Compétences de base en observation et analyse de donnés **

# %%
df4 = pd.read_csv("/content/sample_data/Time_Americans_Spend_Sleeping.csv")

# %%
df4.columns
# Out:
# Index(['index', 'Year', 'Period', 'Avg hrs per day sleeping', 'Standard Error',
#        'Type of Days', 'Age Group', 'Activity', 'Sex'],
#       dtype='object')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB
